# %% [markdown]
# Author:Bhawana
#
# Date:04/02/2026
#
# Roll no.:250241
#
# Course:BCA
#
# Course Code: CA 23.136
#
# Purpose of the program is to perform basic operations on python.

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhawana-30/Pythonprograms/blob/main/Basic_python.ipynb)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c=a+b
print(c)
# Out:
# Enter first number: 5
# Enter second number: 6
# 11

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=a+b
d=a-b
e=a*b
f=a**b
g=a/b
h=a%b
print(c, d, e, f, g, h)
# Out:
# enter first number:12
# enter second number:6
# 18 6 72 2985984 2.0 0

# %%
a="Bhawana"
print(a)
# Out:
# Bhawana

# %%
a="5"
b="Bhawana"
c=a+b
print(c)
# Out:
# 5Bhawana

# %%
a=str(5)
b="Bhawana"
c=a+b
print(c)
# Out:
# 5Bhawana

# %%
b="Bhawana"
a=b
print(a)
# Out:
# Bhawana

# %%
"hello world"
# Out:
# 'hello world'
