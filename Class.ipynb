# %% [markdown]
# Author:  Bhawana
#
# Date: 24-04-26
#
# Course: Python programming
#
# Course Code: CA 23.108
#
# Program: BCA
#
# program to create class.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhawana_30/pythonprograms/blob/main/class.ipynb)

# %%
# make a class
class Cars: #creating an architecture
    # atributes=model,color
    model=2008
    color="red" #method of the car
c1 = Cars() #creating an instance/object
print(c1.color)
print(c1.model)
# Out:
# red
# 2008

# %%
class student:
 name="Bhawana"
 age=18
 weight=48
s1=student()
print(s1.name)
print(s1.age)
print(s1.weight)
# Out:
# Bhawana
# 18
# 48
